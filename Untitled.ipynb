# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Flatten, Dense, BatchNormalization, GlobalAveragePooling2D, Dropout
from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input
import cv2
import numpy as np
import matplotlib.pyplot as plt

def create_model():
    NUM_CLASSES = 2
    base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(150,150,3))
    x = base_model.output
    x = GlobalAveragePooling2D(name='avg_pool')(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.3)(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.3)(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)

    for layer in base_model.layers:
        layer.trainable = False
    predictions = Dense(NUM_CLASSES, activation='sigmoid')(x)
    model = Model(inputs=base_model.inputs, outputs=predictions)
    return model

def initialize_model():

    model = create_model()
    model.load_weights('trained_model/trained_pneumonia_model.h5')

    return model

# %%
def get_image(b_img):

    image = np.asarray(bytearray(b_img), dtype="uint8")
    image = cv2.imdecode(image, cv2.IMREAD_COLOR)
    img = cv2.resize(image, (150,150))
    img = img/255
    
    return img

def classify(b_img):

    model = initialize_model()
    img = get_image(b_img)
    prediction = model.predict([[img]])
    plt.imshow(img)
    x = np.argmax(prediction, axis=1)
    y = np.sum(prediction)
    print("y:")
    print(y)
    print("\n\n{}\n\n".format(list(prediction)))
    return "PNEUMONIA" if prediction[0][1] == 1 else "NORMAL"

# %%
path_n = "/Volumes/KINGSTON/sairaj_ml/pnimoniae/chest_xray/test/NORMAL/"
path_e = "/Volumes/KINGSTON/sairaj_ml/pnimoniae/chest_xray/test/PNEUMONIA/"

# %%
f = open(path_e+"person57_virus_113.jpeg", "rb")
img = f.read()
f.close()

# %%
classify(img)
# Out:
# y:
# 0.8971116
#
#
# [array([5.449830e-05, 8.970571e-01], dtype=float32)]
# 'NORMAL'

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.14.0

# %%
x = tf.keras.models.load_model('trained_model/trained_pneumonia_model.h5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-3f3ad8d91e38> in <module>
# ----> 1 x = tf.keras.models.load_model('trained_model/trained_pneumonia_model.h5')
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile)
#     144       h5py is not None and (
#     145           isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 146     return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#     147
#     148   if isinstance(filepath, six.string_types):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/saving/hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     210     model_config = json.loads(model_config.decode('utf-8'))
#     211     model = model_config_lib.model_from_config(model_config,
# ...

# %%
import tensorflow as tf
def v3_model():
    pretrained_model = tf.keras.applications.inception_v3.InceptionV3(weights='imagenet', input_shape=(224, 224, 3), include_top=False)
    ### QUESTION 1.
    model = tf.keras.Sequential([
        pretrained_model,
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(2, activation='softmax')
    ])
    
    return model

# %% [markdown]
# # Loading my model

# %%
import tensorflow as tf
import numpy as np
import cv2

# %%
def process_image(path):
    image = np.asarray(bytearray(b_img), dtype="uint8")
    image = cv2.imdecode(image, cv2.IMREAD_COLOR)
    img = cv2.resize(image, (224,224))
    img = img/255
    
    return img

# %%
def read_bytes():
    path_n = "/Volumes/KINGSTON/sairaj_ml/pnimoniae/chest_xray/test/NORMAL/"
    path_e = "/Volumes/KINGSTON/sairaj_ml/pnimoniae/chest_xray/test/PNEUMONIA/"
    f = open(path_n+"NORMAL2-IM-0310-0001.jpeg", "rb")
    img = f.read()
    f.close()
    return img

# %%
def get_model():
    pretrained_model = tf.keras.applications.inception_v3.InceptionV3(weights='imagenet', input_shape=(224, 224, 3), include_top=False)
    
    model = tf.keras.Sequential([
        pretrained_model,
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(2, activation='softmax')
    ])
    
    return model

# %%
model = tf.keras.models.load_model('trained_model/v3_weights.h5')


model = get_model()
moel.load_weights('trained_model/v3_weights.h5')

# %%
b_img = read_bytes()
img = process_image(b_img)

# %%
x = model.predict_proba([[img]])

# %%
print(x)
print(np.argmax(x))
# Out:
# [[0.9505987  0.04940132]]
# 0
